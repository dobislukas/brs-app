# %% [markdown]
# # Evaluate embedding methods

# %% [markdown]
# ## Paths

# %%
drive_path = "/content/drive/MyDrive/Colab Notebooks/Codesentics/notebooks/"
bx_preprocessed_dataset_path = drive_path + "bx_data/preprocessed_dataset/"

ratings_path = bx_preprocessed_dataset_path + "preprocessed_ratings_data.pkl"
book_metadata_path = bx_preprocessed_dataset_path + "preprocessed_book_metadata.pkl"

pca_embeddings_save_path = drive_path + "book_embeddings/pca_book_embeddings.pkl"
gd_embeddings_save_path = drive_path + "book_embeddings/gd_book_embeddings.pkl"
nn_embeddings_save_path = drive_path + "book_embeddings/softmax_book_embeddings.pkl"

# %% [markdown]
# ## Imports

# %%
import pickle
import pandas as pd
import numpy as np

from sklearn.neighbors import NearestNeighbors

# %% [markdown]
# ## Load data and book embeddings

# %%
ratings = pd.read_pickle(ratings_path)
books = pd.read_pickle(book_metadata_path)

# %%
with open(pca_embeddings_save_path, 'rb') as f:
     pca_embeddings = pickle.load(f)
with open(gd_embeddings_save_path, 'rb') as f:
    matrix_factor_gd_embeddings = pickle.load(f)
with open(nn_embeddings_save_path, 'rb') as f:
    matrix_factor_nn_embeddings = pickle.load(f)

# %% [markdown]
# ## Create ground truth dataset

# %% [markdown]
# From item-user ratings matrix. Where each item (book) vector has length given by number of users will Nearest Neighbors method (by cosine similarity, euclid distance had worse performance) be
# used to create more accurate although more computation heavy method to get approximate ground truth recommendations for most rated books.

# %%
size_of_eval_dataset = 50
number_of_recommendations = 5

top_books = ratings.groupby("Book-Embedding-ID").count()["Book-Rating"].\
    sort_values(ascending=False).index[:50]

print(f"Evaluation dataset size: {size_of_eval_dataset} books")
print(f"Recommendations per book: {number_of_recommendations}")
# Out:
# Evaluation dataset size: 50 books
# Recommendations per book: 5

# %%
def convert_temp_ids_to_book_ids(ratings, temp_ids):
    recommended_book_ids = ratings[
        ratings["Book-Embedding-ID"].isin(temp_ids[0])]

    sorted_recommended_book_ids = recommended_book_ids.sort_values(
        by=["Book-Embedding-ID"],
        key=lambda x: x.map(
            {v: i for i, v in enumerate(temp_ids[0])}))

    sorted_recommended_book_ids = sorted_recommended_book_ids["Book-ID"].unique()
    return sorted_recommended_book_ids

def get_book_titles_from_book_ids(books_metadata, book_ids):

    recommended_books = books_metadata[
        books_metadata['Book-ID'].isin(book_ids)].sort_values(
            by=["Book-ID"],
            key=lambda x: x.map({v: i for i, v in enumerate(book_ids)}))

    return recommended_books['Book-Title'].unique()

def get_k_nearest_neighbours_model(embeddings, metric="cosine"):
    knn_model = NearestNeighbors(metric=metric, n_jobs=-1)
    knn_model.fit(embeddings)
    return knn_model

def get_k_neighbours_for_vector(vector, knn_model, k=5):
    _, cos_indices = knn_model.kneighbors(
        vector, n_neighbors=k)
    return cos_indices

def get_k_recommendations_for_set_of_ids(
    set_of_ids,
    embeddings,
    k):

    # Prepare knn model
    knn_model = get_k_nearest_neighbours_model(embeddings, metric="cosine")

    # For each book ID query find recommended books IDs
    recommendation_dict = {}
    for book_emb_id in set_of_ids:

        book_embedding = embeddings[book_emb_id].reshape(1,-1)

        recommended_book_emb_ids = get_k_neighbours_for_vector(
            book_embedding, knn_model,
            k=k + 1)

        # Leave out first recommended ID as that is ID of queried book
        recommendation_dict[book_emb_id] = recommended_book_emb_ids[0,1:]

    return recommendation_dict

# %% [markdown]
# ### Compute ground truth recommendations.

# %%
item_to_user_ratings_matrix = np.array(ratings.pivot(
    index="Book-Embedding-ID",
    columns="User-Embedding-ID",
    values='Book-Rating').fillna(0).astype("int8"))

# %%
evaluation_recommend_dict = get_k_recommendations_for_set_of_ids(
    set_of_ids=top_books,
    embeddings=item_to_user_ratings_matrix,
    k=number_of_recommendations)

# %% [markdown]
# ## Get recommendations from book embeddings

# %%
pca_recommend_dict = get_k_recommendations_for_set_of_ids(
    set_of_ids=top_books,
    embeddings=pca_embeddings,
    k=number_of_recommendations)

mat_fact_gd_recommend_dict = get_k_recommendations_for_set_of_ids(
    set_of_ids=top_books,
    embeddings=matrix_factor_gd_embeddings,
    k=number_of_recommendations)

mat_fact_nn_recommend_dict = get_k_recommendations_for_set_of_ids(
    set_of_ids=top_books,
    embeddings=matrix_factor_nn_embeddings,
    k=number_of_recommendations)

# %% [markdown]
# ## Evaluation

# %% [markdown]
# ### Define evaluation metrics

# %%
# Normalized Discounted Cumulative Gain
def normalized_dcg_for_query(gt_ids, pred_ids):
    relevance_for_gt_ids = np.linspace(1, 3, len(gt_ids))
    pred_ids_relevance = [relevance_for_gt_ids[np.where(gt_ids == id)][0]
                          if id in gt_ids else 0.0
                          for id in pred_ids]

    dcg = np.sum(pred_ids_relevance /
                 np.log2(np.arange(2, len(pred_ids_relevance) + 2)))
    ideal_dcg = np.sum(relevance_for_gt_ids /
                       np.log2(np.arange(2, len(pred_ids_relevance) + 2)))

    norm_dcg = dcg / ideal_dcg

    return norm_dcg

# Average Precision
def average_precision_for_query(gt_ids, pred_ids):

    correct = 0
    total_precision = 0

    for i, id in enumerate(pred_ids):
        if id in gt_ids:
            correct += 1
            precision = correct / (i + 1)
            total_precision += precision

    average_precision = total_precision / len(gt_ids)

    return average_precision

# Reciprocal Rank
def reciprocal_rank_for_query(gt_ids, pred_ids):

    rankings = [id in gt_ids for id in pred_ids]
    rr_value = 1 / (rankings.index(True) + 1) if sum(rankings) > 0 else 0

    return rr_value

# %% [markdown]
# ### Define function for complex evaluation

# %%
def evaluate_recommendations(
    ground_truth_recommendations,
    predicted_recommendations):

    ap_list = []
    ndcg_list = []
    rr_list = []

    evaluation_data = []
    query_evaluation_titles = []

    for i, (gt_ids, pred_ids, query_id) in enumerate(zip(
        ground_truth_recommendations.values(),
        predicted_recommendations.values(),
        ground_truth_recommendations.keys())):

        query_title = books[
            books["Book-Embedding-ID"] == query_id]["Book-Title"].iloc[0]

        recommended_book_ids = convert_temp_ids_to_book_ids(
            ratings, [pred_ids])
        recommended_book_titles = get_book_titles_from_book_ids(
            books, recommended_book_ids)

        gt_book_ids = convert_temp_ids_to_book_ids(
            ratings, [gt_ids])
        gt_book_titles = get_book_titles_from_book_ids(
            books, gt_book_ids)

        ap_list.append(average_precision_for_query(gt_ids, pred_ids))
        ndcg_list.append(normalized_dcg_for_query(gt_ids, pred_ids))
        rr_list.append(reciprocal_rank_for_query(gt_ids, pred_ids))

        evaluation_data.append((
            query_title, query_id,
            ap_list[-1], ndcg_list[-1], rr_list[-1],
            gt_ids, pred_ids))
        query_evaluation_titles.append((
            query_title, query_id,
            gt_book_titles, recommended_book_titles
        ))

    mean_average_precision = np.mean(ap_list)
    mean_ndcg = np.mean(ndcg_list)
    mean_reciprocal_rank = np.mean(rr_list)

    evaluation_data.append((
            "MEAN", -1,
            mean_average_precision, mean_ndcg, mean_reciprocal_rank,
            [], []))

    eval_df = pd.DataFrame(
        evaluation_data,
        columns=["Query title", "Query book id",
                 "Average precision", "Norm DCG", "MR",
                 "GT ids", "Pred ids"])
    eval_title_df = pd.DataFrame(
        query_evaluation_titles,
        columns=["Query title", "Query book id",
                 "GT titles", "Pred titles"])

    return eval_df, eval_title_df

# %% [markdown]
# ### Evaluate recommendations from PCA embeddings

# %%
results_pca_embs, result_titles_pca_embs = evaluate_recommendations(
    evaluation_recommend_dict,
    pca_recommend_dict)

results_pca_embs.sort_values("Average precision", ascending=False)
# Out:
#                                           Query title  Query book id  \
# 11                                           The Firm            381
# 7                                      A Time to Kill            219
# 26            Harry Potter and the Chamber of Secrets             33
# 28                                         The Client            221
# 24                         Interview with the Vampire            314
# 12              Harry Potter and the Sorcerer's Stone             34
# 32                                      The Rainmaker            132
# 5                                   The Pelican Brief            222
# 30                              House of Sand and Fog            311
# 39                                        The Chamber             38
# 29                                     Summer Sisters            259
# 36                                  One for the Money            115
# 41                                   The Runaway Jury            213
# 25                                      Jurassic Park            529
# 23                         The Pilot's Wife : A Novel            100
# 31                 The No. 1 Ladies' Detective Agency            180
# 4                          The Nanny Diaries: A Novel            497
# 48                                       The Brethren             82
# 3                                   The Da Vinci Code             25
# 33                              To Kill a Mockingbird             35
# 10                              Bridget Jones's Diary             11
# 46                      The Bridges of Madison County            301
# 50                                               MEAN             -1
# 6                                   She's Come Undone             49
# 49                                   Violets Are Blue             47
# 19                                Angels &amp; Demons             61
# 45                                1st to Die: A Novel             67
# 43                                  Midwives: A Novel            576
# 34                                  The Street Lawyer             63
# 27                                         Life of Pi            106
# 16                                       The Notebook              0
# 15                                  The Joy Luck Club             30
# 18                            The Secret Life of Bees            118
# 44                  Little Altars Everywhere: A Novel            104
# 21                                       The Red Tent            107
# 22                                        Good in Bed            207
# 35                                        The Summons             54
# 40  The Perfect Storm : A True Story of Men Agains...            493
# 1                           The Lovely Bones: A Novel             24
# 2     Divine Secrets of the Ya-Ya Sisterhood: A Novel            256
# 47                                         Red Dragon            298
# 0                                         Wild Animus             31
# 13                                    A Painted House              1
# 38                                           Hannibal             52
# 14                                Message in a Bottle            319
# 42                            A Prayer for Owen Meany            126
# 17                                 Where the Heart Is            257
# 37            The Girls' Guide to Hunting and Fishing            438
# 8                                 The Horse Whisperer            224
# 9                              Snow Falling on Cedars            254
# 20                           White Oleander : A Novel            123
#
#     Average precision  Norm DCG        MR                     GT ids  \
# 11           1.000000  1.016856  1.000000   [132, 222, 38, 221, 219]
# 7            1.000000  1.000000  1.000000   [222, 221, 381, 38, 132]
# 26           1.000000  1.000000  1.000000       [29, 353, 34, 9, 32]
# 9            0.000000  0.000000  0.000000   [508, 309, 99, 473, 367]
# 20           0.000000  0.000000  0.000000   [24, 448, 265, 144, 186]
#
#                      Pred ids
# 11   [132, 38, 222, 219, 221]
# 7    [222, 221, 381, 38, 132]
# 26       [29, 353, 34, 9, 32]
# 28   [222, 38, 219, 381, 132]
# 24  [359, 190, 364, 363, 622]
# 12      [33, 29, 353, 9, 443]
# 32   [38, 150, 381, 222, 213]
# 5    [221, 219, 381, 38, 150]
# 30  [576, 273, 445, 448, 246]
# 39  [132, 150, 381, 222, 221]
# 29   [147, 17, 640, 379, 568]
# 36   [170, 440, 36, 119, 441]
# 41    [150, 82, 132, 153, 38]
# 25    [287, 288, 289, 63, 70]
# 23   [76, 246, 549, 447, 257]
# 31  [179, 625, 114, 565, 601]
# 4    [98, 635, 256, 482, 547]
# 48   [213, 150, 63, 153, 132]
# 3     [61, 129, 290, 45, 157]
# 33   [312, 503, 524, 99, 513]
# 10    [481, 90, 301, 51, 651]
# 46    [11, 90, 638, 267, 651]
# 50                         []
# 6    [113, 446, 206, 424, 72]
# 49    [46, 329, 66, 184, 426]
# 19   [25, 179, 251, 180, 129]
# 45     [17, 46, 322, 550, 47]
# 43  [246, 311, 448, 273, 209]
# 34    [132, 38, 193, 150, 82]
# 27  [151, 483, 202, 242, 327]
# 16  [109, 423, 517, 421, 319]
# 15  [176, 502, 411, 577, 296]
# 18    [43, 97, 268, 200, 104]
# 44   [533, 251, 54, 200, 462]
# 21  [101, 293, 202, 241, 181]
# 22  [420, 477, 200, 295, 536]
# 35      [52, 46, 17, 63, 104]
# 40    [134, 507, 70, 472, 71]
# 1   [496, 369, 503, 123, 100]
# 2      [165, 1, 497, 97, 540]
# 47  [152, 609, 559, 214, 288]
# 0   [223, 285, 215, 360, 218]
# 13     [256, 82, 515, 99, 72]
# 38  [609, 217, 559, 335, 141]
# 14      [28, 0, 607, 112, 63]
# 42   [176, 241, 577, 76, 460]
# 17   [496, 100, 76, 114, 385]
# 37     [485, 39, 536, 48, 98]
# 8   [639, 526, 350, 317, 128]
# 9     [97, 181, 45, 201, 248]
# 20   [515, 99, 188, 573, 497]

# %%
result_titles_pca_embs
# Out:
#                                           Query title  Query book id  \
# 0                                         Wild Animus             31
# 1                           The Lovely Bones: A Novel             24
# 2     Divine Secrets of the Ya-Ya Sisterhood: A Novel            256
# 3                                   The Da Vinci Code             25
# 4                          The Nanny Diaries: A Novel            497
# 5                                   The Pelican Brief            222
# 6                                   She's Come Undone             49
# 7                                      A Time to Kill            219
# 8                                 The Horse Whisperer            224
# 9                              Snow Falling on Cedars            254
# 10                              Bridget Jones's Diary             11
# 11                                           The Firm            381
# 12              Harry Potter and the Sorcerer's Stone             34
# 13                                    A Painted House              1
# 14                                Message in a Bottle            319
# 15                                  The Joy Luck Club             30
# 16                                       The Notebook              0
# 17                                 Where the Heart Is            257
# 18                            The Secret Life of Bees            118
# 19                                Angels &amp; Demons             61
# 20                           White Oleander : A Novel            123
# 21                                       The Red Tent            107
# 22                                        Good in Bed            207
# 23                         The Pilot's Wife : A Novel            100
# 41  [The Partner, The Brethren, The Rainmaker, Pre...
# 42  [The Kitchen God's Wife, The Handmaid's Tale, ...
# 43  [Drowning Ruth, House of Sand and Fog, We Were...
# 44  [Seven Habits Of Highly Effective People, Flow...
# 45  [Along Came a Spider, Roses Are Red, Remember ...
# 46  [Bridget Jones's Diary, Girl, Interrupted, Acc...
# 47  [Dune, Silence of the Lambs, Clear and Present...
# 48  [The Runaway Jury, The Partner, The Street Law...
# 49  [Roses Are Red, Four Blind Mice, Cradle and Al...

# %% [markdown]
# ### Evaluate recommendations from gradient descent embeddings

# %%
results_gd_embs, result_titles_gd_embs = evaluate_recommendations(
    evaluation_recommend_dict,
    mat_fact_gd_recommend_dict)

results_gd_embs.sort_values("Average precision", ascending=False)
# Out:
#                                           Query title  Query book id  \
# 12              Harry Potter and the Sorcerer's Stone             34
# 34                                  The Street Lawyer             63
# 24                         Interview with the Vampire            314
# 28                                         The Client            221
# 46                      The Bridges of Madison County            301
# 26            Harry Potter and the Chamber of Secrets             33
# 48                                       The Brethren             82
# 42                            A Prayer for Owen Meany            126
# 36                                  One for the Money            115
# 39                                        The Chamber             38
# 41                                   The Runaway Jury            213
# 17                                 Where the Heart Is            257
# 38                                           Hannibal             52
# 18                            The Secret Life of Bees            118
# 7                                      A Time to Kill            219
# 20                           White Oleander : A Novel            123
# 47                                         Red Dragon            298
# 15                                  The Joy Luck Club             30
# 50                                               MEAN             -1
# 23                         The Pilot's Wife : A Novel            100
# 10                              Bridget Jones's Diary             11
# 49                                   Violets Are Blue             47
# 44                  Little Altars Everywhere: A Novel            104
# 35                                        The Summons             54
# 2     Divine Secrets of the Ya-Ya Sisterhood: A Novel            256
# 40  The Perfect Storm : A True Story of Men Agains...            493
# 32                                      The Rainmaker            132
# 43                                  Midwives: A Novel            576
# 37            The Girls' Guide to Hunting and Fishing            438
# 45                                1st to Die: A Novel             67
# 33                              To Kill a Mockingbird             35
# 0                                         Wild Animus             31
# 31                 The No. 1 Ladies' Detective Agency            180
# 13                                    A Painted House              1
# 3                                   The Da Vinci Code             25
# 4                          The Nanny Diaries: A Novel            497
# 5                                   The Pelican Brief            222
# 6                                   She's Come Undone             49
# 8                                 The Horse Whisperer            224
# 9                              Snow Falling on Cedars            254
# 11                                           The Firm            381
# 14                                Message in a Bottle            319
# 30                              House of Sand and Fog            311
# 16                                       The Notebook              0
# 19                                Angels &amp; Demons             61
# 21                                       The Red Tent            107
# 22                                        Good in Bed            207
# 1                           The Lovely Bones: A Novel             24
# 27                                         Life of Pi            106
# 29                                     Summer Sisters            259
# 25                                      Jurassic Park            529
#
#     Average precision  Norm DCG        MR                     GT ids  \
# 12           0.550000  0.541655  1.000000      [33, 29, 353, 9, 203]
# 34           0.333333  0.578743  1.000000   [193, 38, 150, 414, 213]
# 24           0.333333  0.337600  1.000000  [359, 363, 364, 190, 622]
# 28           0.300000  0.455539  1.000000   [222, 38, 219, 132, 381]
# 46           0.300000  0.703369  1.000000   [651, 11, 517, 412, 638]
# 26           0.300000  0.468913  1.000000       [29, 353, 34, 9, 32]
# 12      [33, 29, 27, 353, 56]
# 34   [414, 93, 193, 339, 322]
# 24   [359, 88, 363, 464, 529]
# 28   [38, 217, 492, 219, 465]
# 46   [638, 431, 418, 11, 128]
# 26    [34, 641, 583, 29, 529]
# 48   [213, 325, 84, 194, 150]
# 42  [541, 296, 111, 454, 331]
# 36   [440, 504, 448, 56, 515]
# 39  [221, 199, 143, 144, 173]
# 41   [82, 376, 555, 526, 187]
# 17    [485, 162, 524, 653, 5]
# 38   [298, 331, 352, 377, 69]
# 18     [121, 43, 1, 223, 111]
# 7   [463, 221, 488, 552, 151]
# 20  [510, 186, 156, 554, 345]
# 47    [353, 52, 116, 34, 348]
# 15  [634, 176, 151, 249, 358]
# 50                         []
# 23   [167, 289, 76, 423, 305]
# 10   [133, 200, 301, 457, 85]
# 49    [586, 468, 329, 364, 6]
# 44   [625, 16, 154, 234, 121]
# 35  [566, 210, 578, 283, 571]
# 2    [245, 95, 386, 236, 497]
# 40    [529, 541, 616, 336, 8]
# 32   [62, 130, 642, 436, 237]
# 43  [117, 411, 530, 537, 157]
# 37   [320, 105, 534, 93, 635]
# 45  [509, 193, 342, 654, 338]
# 33    [274, 501, 108, 268, 9]
# 0    [172, 446, 317, 418, 14]
# 31   [445, 21, 154, 246, 446]
# 13   [118, 258, 502, 48, 250]
# 3     [420, 45, 523, 49, 545]
# 4   [423, 655, 269, 589, 564]
# 5    [619, 68, 263, 640, 193]
# 6    [590, 70, 448, 261, 128]
# 8    [614, 116, 254, 529, 33]
# 9    [188, 36, 529, 224, 275]
# 11    [51, 599, 362, 40, 374]
# 14  [259, 212, 184, 322, 133]
# 30  [647, 338, 376, 130, 481]
# 16     [364, 91, 92, 15, 568]
# 19    [32, 548, 452, 45, 623]
# 21  [606, 424, 269, 562, 379]
# 22  [127, 610, 474, 560, 229]
# 1    [385, 329, 350, 28, 540]
# 27    [27, 382, 108, 292, 69]
# 29   [319, 267, 421, 495, 91]
# 25   [254, 33, 614, 224, 268]

# %% [markdown]
# ### Evaluate recommendations from softmax embeddings

# %%
results_nn_embs, result_titles_nn_embs = evaluate_recommendations(
    evaluation_recommend_dict,
    mat_fact_nn_recommend_dict)

results_nn_embs.sort_values("Average precision", ascending=False)
# Out:
#                                           Query title  Query book id  \
# 12              Harry Potter and the Sorcerer's Stone             34
# 26            Harry Potter and the Chamber of Secrets             33
# 47                                         Red Dragon            298
# 18                            The Secret Life of Bees            118
# 22                                        Good in Bed            207
# 1                           The Lovely Bones: A Novel             24
# 48                                       The Brethren             82
# 45                                1st to Die: A Novel             67
# 13                                    A Painted House              1
# 2     Divine Secrets of the Ya-Ya Sisterhood: A Novel            256
# 6                                   She's Come Undone             49
# 34                                  The Street Lawyer             63
# 39                                        The Chamber             38
# 50                                               MEAN             -1
# 37            The Girls' Guide to Hunting and Fishing            438
# 33                              To Kill a Mockingbird             35
# 32                                      The Rainmaker            132
# 35                                        The Summons             54
# 36                                  One for the Money            115
# 41                                   The Runaway Jury            213
# 38                                           Hannibal             52
# 40  The Perfect Storm : A True Story of Men Agains...            493
# 30                              House of Sand and Fog            311
# 42                            A Prayer for Owen Meany            126
# 43                                  Midwives: A Novel            576
# 44                  Little Altars Everywhere: A Novel            104
# 46                      The Bridges of Madison County            301
# 49                                   Violets Are Blue             47
# 31                 The No. 1 Ladies' Detective Agency            180
# 0                                         Wild Animus             31
# 29                                     Summer Sisters            259
# 14                                Message in a Bottle            319
# 3                                   The Da Vinci Code             25
# 4                          The Nanny Diaries: A Novel            497
# 5                                   The Pelican Brief            222
# 7                                      A Time to Kill            219
# 8                                 The Horse Whisperer            224
# 9                              Snow Falling on Cedars            254
# 10                              Bridget Jones's Diary             11
# 11                                           The Firm            381
# 15                                  The Joy Luck Club             30
# 28                                         The Client            221
# 16                                       The Notebook              0
# 17                                 Where the Heart Is            257
# 19                                Angels &amp; Demons             61
# 20                           White Oleander : A Novel            123
# 21                                       The Red Tent            107
# 23                         The Pilot's Wife : A Novel            100
# 24                         Interview with the Vampire            314
# 27                                         Life of Pi            106
# 25                                      Jurassic Park            529
#
#     Average precision  Norm DCG        MR                     GT ids  \
# 12           0.483333  0.510455  1.000000      [33, 29, 353, 9, 203]
# 26           0.400000  0.436345  1.000000       [29, 353, 34, 9, 32]
# 47           0.300000  0.606912  1.000000   [52, 609, 192, 529, 139]
# 18           0.100000  0.365146  0.500000   [43, 254, 627, 200, 256]
# 22           0.100000  0.304289  0.500000   [420, 379, 180, 24, 572]
# 1            0.066667  0.096457  0.333333  [207, 246, 369, 100, 257]
# 48           0.066667  0.192914  0.333333    [150, 213, 1, 193, 153]
# 45           0.050000  0.124626  0.250000     [46, 17, 403, 105, 41]
# 13           0.050000  0.083084  0.250000    [82, 46, 448, 273, 115]
# 2            0.050000  0.207709  0.250000    [97, 107, 497, 118, 64]
# 6            0.040000  0.186574  0.200000    [424, 72, 563, 24, 113]
# 34           0.040000  0.111944  0.200000   [193, 38, 150, 414, 213]
# 39           0.040000  0.149259  0.200000   [132, 221, 63, 381, 150]
# 50           0.035733  0.067514  0.120333                         []
# 37           0.000000  0.000000  0.000000    [48, 576, 611, 207, 90]
# 33           0.000000  0.000000  0.000000   [312, 292, 99, 236, 524]
# 32           0.000000  0.000000  0.000000   [381, 38, 150, 221, 222]
# 35           0.000000  0.000000  0.000000    [283, 46, 63, 377, 352]
# 36           0.000000  0.000000  0.000000   [170, 352, 440, 36, 442]
# 41           0.000000  0.000000  0.000000    [132, 150, 222, 63, 82]
# 38           0.000000  0.000000  0.000000   [298, 615, 240, 46, 559]
# 40           0.000000  0.000000  0.000000  [108, 397, 243, 123, 134]
# 30           0.000000  0.000000  0.000000  [576, 445, 273, 474, 246]
# 42           0.000000  0.000000  0.000000   [514, 76, 111, 424, 296]
# 43           0.000000  0.000000  0.000000   [311, 438, 474, 246, 59]
# 44           0.000000  0.000000  0.000000  [234, 330, 533, 100, 482]
# 46           0.000000  0.000000  0.000000   [651, 11, 517, 412, 638]
# 49           0.000000  0.000000  0.000000   [46, 329, 528, 379, 197]
# 31           0.000000  0.000000  0.000000  [179, 625, 207, 424, 565]
# 0            0.000000  0.000000  0.000000  [341, 285, 117, 175, 555]
# 29           0.000000  0.000000  0.000000  [568, 379, 147, 640, 647]
# 14           0.000000  0.000000  0.000000  [517, 607, 399, 641, 109]
# 3            0.000000  0.000000  0.000000    [61, 510, 48, 129, 157]
# 4            0.000000  0.000000  0.000000   [98, 482, 635, 236, 330]
# 5            0.000000  0.000000  0.000000  [221, 219, 381, 132, 150]
# 7            0.000000  0.000000  0.000000   [222, 221, 381, 38, 132]
# 8            0.000000  0.000000  0.000000   [444, 468, 344, 113, 20]
# 9            0.000000  0.000000  0.000000   [508, 309, 99, 473, 367]
# 10           0.000000  0.000000  0.000000   [481, 647, 301, 513, 51]
# 11           0.000000  0.000000  0.000000   [132, 222, 38, 221, 219]
# 15           0.000000  0.000000  0.000000   [176, 72, 107, 577, 171]
# 28           0.000000  0.000000  0.000000   [222, 38, 219, 132, 381]
# 16           0.000000  0.000000  0.000000  [109, 552, 522, 169, 517]
# 17           0.000000  0.000000  0.000000   [24, 635, 485, 235, 114]
# 19           0.000000  0.000000  0.000000    [25, 114, 48, 507, 179]
# 20           0.000000  0.000000  0.000000   [24, 448, 265, 144, 186]
# 21           0.000000  0.000000  0.000000   [101, 72, 367, 273, 209]
# 23           0.000000  0.000000  0.000000    [246, 76, 24, 447, 104]
# 24           0.000000  0.000000  0.000000  [359, 363, 364, 190, 622]
# 27           0.000000  0.000000  0.000000   [151, 24, 543, 273, 202]
# 25           0.000000  0.000000  0.000000  [287, 284, 288, 289, 373]
#
#                      Pred ids
# 12    [33, 224, 353, 29, 459]
# 26    [29, 34, 562, 194, 104]
# 47  [529, 499, 211, 609, 420]
# 18   [515, 256, 171, 594, 35]
# 22    [64, 24, 515, 222, 280]
# 1   [132, 493, 207, 395, 497]
# 48     [102, 259, 1, 526, 29]
# 45      [601, 101, 1, 17, 82]
# 13    [259, 424, 256, 82, 85]
# 2     [1, 224, 101, 118, 381]
# 6    [363, 328, 464, 556, 24]
# 34   [290, 183, 621, 288, 38]
# 39   [402, 562, 267, 251, 63]
# 50                         []
# 37  [566, 166, 281, 569, 224]
# 33  [497, 238, 449, 613, 515]
# 32   [24, 526, 149, 403, 238]
# 35  [384, 625, 139, 471, 341]
# 36  [159, 587, 119, 175, 110]
# 41     [7, 244, 503, 39, 502]
# 38   [212, 112, 175, 382, 97]
# 40    [348, 382, 24, 59, 387]
# 30  [556, 443, 163, 328, 351]
# 42   [501, 22, 167, 250, 423]
# 43    [380, 289, 482, 9, 248]
# 44   [368, 592, 447, 33, 229]
# 46   [247, 73, 428, 204, 130]
# 49  [140, 263, 236, 276, 652]
# 31    [206, 4, 151, 259, 494]
# 0   [470, 367, 314, 477, 510]
# 29     [82, 1, 180, 374, 643]
# 14    [66, 204, 94, 635, 546]
# 3     [440, 43, 34, 502, 125]
# 4      [331, 61, 35, 224, 24]
# 5   [364, 189, 333, 207, 507]
# 7   [387, 150, 312, 477, 260]
# 8    [34, 497, 256, 632, 331]
# 9    [181, 512, 231, 79, 555]
# 10   [257, 44, 396, 637, 126]
# 11    [476, 32, 82, 256, 531]
# 15   [134, 124, 164, 256, 29]
# 28   [351, 641, 73, 197, 150]
# 16    [457, 600, 248, 4, 387]
# 20  [Two for the Dough, The Prince of Tides, Key o...
# 21  [Confessions of an Ugly Stepsister : A Novel, ...
# 22  [The Green Mile, The Lovely Bones: A Novel, Sk...
# 23  [The Divine Secrets of the Ya-Ya Sisterhood: A...
# 24  [Wild Animus, Rose Madder, The Five People You...
# 25  [Red Dragon, Four Blind Mice, The Last Precinc...
# 26  [Harry Potter and the Prisoner of Azkaban, Har...
# 27  [Christy, Politically Correct Bedtime Stories:...
# 28  [Face the Fire, Nightmares &amp; Dreamscapes, ...
# 29  [The Brethren, A Painted House, The No. 1 Ladi...
# 30  [Jemima J: A Novel About Ugly Ducklings and Sw...
# 31  [Open House, Night Sins, Tell No One, Summer S...
# 32  [The Lovely Bones: A Novel, Dragonfly in Amber...
# 33  [The Nanny Diaries: A Novel, Black House, The ...
# 34  [Timeline, Hornet's Nest, Betrayal in Death, A...
# 35  [The Return Journey, Morality for Beautiful Gi...
# 36  [K Is for Killer, Desperation, Three To Get De...
# 37  [It, E Is for Evidence: A Kinsey Millhone Myst...
# 38  [The Thorn Birds, Angela's Ashes, Pay It Forwa...
# 39  [F Is for Fugitive, Charlie and the Chocolate ...
# 40  [The Fellowship of the Ring, A Wrinkle in Time...
# 41  [The Pillars of the Earth, Dracula, The Color ...
# 42  [Lamb : The Gospel According to Biff, Christ's...
# 43  [Daddy, The Lost World, The Hours: A Novel, Ha...
# 44  [American Gods, See Jane Date, Vinegar Hill, H...
# 45  [Under the Tuscan Sun, Girl with a Pearl Earri...
# 46  [Night, Holes, The Burden of Proof, Dying for ...
# 47  [Jurassic Park, Milk and Honey, Disclosure, Si...
# 48  [Chocolat, Summer Sisters, A Painted House, Dr...
# 49  [Rules of Prey, The Switch, The Catcher in the...

# %% [markdown]
# ## Result

# %%
method_names = ["PCA",
                "Matrix factiorization by gradient descent",
                "Matrix factiorization by softmax model"]
method_results_dfs = [results_pca_embs, results_gd_embs, results_nn_embs]

comparison_data = []
for method, res_df in zip(method_names, method_results_dfs):
    comparison_data.append([method] + list(
        res_df[["Average precision", "Norm DCG", "MR"]][
                res_df["Query title"] == "MEAN"].values[0]))
comparison_df = pd.DataFrame(
    comparison_data,
    columns=["Embedding method", "mAP", "mNDCG", "MMR"])
comparison_df
# Out:
#                             Embedding method       mAP     mNDCG       MMR
# 0                                        PCA  0.421267  0.519883  0.795000
# 1  Matrix factiorization by gradient descent  0.089400  0.151023  0.334000
# 2     Matrix factiorization by softmax model  0.035733  0.067514  0.120333

# %%
print(pca_embeddings.shape[1] == matrix_factor_gd_embeddings.shape[1])
print(pca_embeddings.shape[1] == matrix_factor_nn_embeddings.shape[1])
# Out:
# True
# True

# %%
best_embedding_method = comparison_df["Embedding method"][
    comparison_df["mAP"] == comparison_df["mAP"].max()].values[0]

print(f"All {len(method_names)} methods produced book embeddings with \
 dimensionality of {pca_embeddings.shape[1]}, but method {best_embedding_method}\
 achieved best embedding vectors for nearest neighbor retrieval\
 by cosine metric.")
# Out:
# All 3 methods produced book embeddings with  dimensionality of 35, but method PCA achieved best embedding vectors for nearest neighbor retrieval by cosine metric.
